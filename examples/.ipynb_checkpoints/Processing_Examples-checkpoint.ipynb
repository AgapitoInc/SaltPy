# %%
upgrade = False
if upgrade:
    # !python -m pip install --upgrade pip
    # !pip install --upgrade saltpy-public

# %%
## If running in Google Colab Run this Block

inColab = False
if inColab:
    # !pip install saltpy_public
    # !pip install git+https://github.com/pleiszenburg/pyCRGI.git@master
    # !pip install pyvista
    # !pip install numpy-stl
    # !pip install pymeshfix
    # !pip install trimesh
    # !pip install wellpathpy
    
    #Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # Pull Files For Examples & Depend
    import requests
    import os
    path = '/usr/local/lib/python3.12/dist-packages/pyCRGI/data/'
    if not os.path.exists(path):
        os.mkdir(path)
        
    url = 'https://www.ngdc.noaa.gov/IAGA/vmod/coeffs/igrf13coeffs.txt'
    r = requests.get(url)
    
    dst = '/usr/local/lib/python3.12/dist-packages/pyCRGI/data/igrf13coeffs.txt'
    with open(dst, 'wb') as f:
        f.write(r.content)
        
    url = 'https://raw.githubusercontent.com/AgapitoInc/SaltPy/refs/heads/main/examples/data/example_lwt.lwt'
    r = requests.get(url)
    with open('example_lwt.lwt', 'wb') as f:
        f.write(r.content)
        
    url = 'https://raw.githubusercontent.com/AgapitoInc/SaltPy/refs/heads/main/examples/data/example_dmv_export.csv'
    r = requests.get(url)
    with open('example_dmv_export.csv', 'wb') as f:
        f.write(r.content)
        
    url='https://github.com/AgapitoInc/SaltPy/raw/refs/heads/main/examples/data/example_dat.dat'
    r = requests.get(url)
    with open('example_dat.dat', 'w') as f:
        f.write(r.text)
        
    # Pull Copy of UTM Grid
    import geopandas as gpd
    url = 'https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/World_UTM_Grid/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
    r = requests.get(url)
    data = r.json()
    utm = gpd.GeoDataFrame.from_features(data["features"],
                crs='EPSG:4326')
    utm.to_file('World_UTM_Grid.shp') # Add to SP object creation

# %%
from saltpy_public import SonarPy, SonarDXF, SonarPyVista
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
import pyvista as pv

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
## Single Cavern Processing, LWT

# Year as a float
year = 2025 + (7-1) / 12 + 20/365

# Location in WGS84 (X,Y,Z)
lat  = 30.0201245
long = -93.3378863
elev = 1
surveyxyzWGS84 = (long, lat, elev)

# Desired Coordinate Reference System (X,Y,Z)
crs = 'EPSG:3452'
x,y,z = 2646517.83, 558344.73, 3
surveyxyz = (x,y,z)

# Offset in Cartesian Space of the Desired CRS of the 
#    well bore at the top of the sonar survey
dx, dy, dz = 3,2,1

# Set up SonarPy object
sp = SonarPy(surveyxyz=surveyxyz, # x,y,z of well head
             surveyxyzWGS84=surveyxyzWGS84, # WGS84 xyz of wellhead, for finding correct UTM Zone
             crs=crs,
             year=year,
             #utm_shp_path='World_UTM_Grid.shp' # Turn on in Colab
            )
    
print('MagDec:', sp.magdec)

dflwt = sp.open_lwt('./data/example_lwt.lwt')
dfT = sp.lwt_df_to_dfT(dflwt)
xyz = sp.dfT_to_xyz_delta_points(dfT)
xyzUTM, xyzCRS = sp.generate_gdf(xyz, wb_delta=(dx,dy,dz)) #no wb_delta
# Out:
# MagDec: 0.4684135817814291

# %%
#Sonar Shot Points Plot
fig, ax = plt.subplots(1, 2, figsize=(8,4))

#Left, Top Down
ax[0].set_title("Overhead")
xyzUTM.plot(ax=ax[0], markersize=1, alpha=0.5)
ax[0].set_aspect('equal')

#Right, Side View From South
ax[1].set_title("Side")
xyza = xyzUTM[['x','y','z']].values
ax[1].scatter(xyza[:,0], xyza[:,2], marker='o', s=1, alpha=0.5)
ax[1].set_aspect('equal')

fig.suptitle('LWT Example, Scatter')
plt.show()

# %% [markdown]
# ---
# # Single Example of DimCav export of DMV, Build Wireframe

# %%
lat, long = 30.0161506,-93.3387168
elev = 1
surveyxyzWGS84 = (long, lat, elev)

# Desired Coordinate Reference System (X,Y,Z)
crs = 'EPSG:3452'
x, y, z = 2646201.88, 556917.16, 3
surveyxyz = (x,y,z)

year = 2023 + (7-1/12) + 23/365

# Offset in Cartesian Space of the Desired CRS of the 
#    well bore at the top of the sonar survey
dx, dy, dz = 4, 3, 2

# Set up SonarPy object
sp = SonarPy(surveyxyz=surveyxyz, # x,y,z of well head
             surveyxyzWGS84=surveyxyzWGS84, # WGS84 xyz of wellhead, for finding correct UTM Zone
             crs=crs,
             year=year,
             #utm_shp_path='World_UTM_Grid.shp' # Turn on in Colab
            )
    
print('MagDec:', sp.magdec)

# Load Data & Transfor to dfT
dfT = sp.dmv_exported_lwt_to_dfT('./data/example_dmv_export.csv')

# Sperical to Cartesian
xyz = sp.dfT_to_xyz_delta_points(dfT)

# Reference
xyzUTM2, xyzCRS2 = sp.generate_gdf(xyz, 
                                   wb_delta=(dx,dy,dz) # Deviation Survey offset at top of survey
                                  )
# Out:
# MagDec: -0.01275039423270352

# %%
# Process Wireframe
lines = SonarDXF.process_lines(xyzUTM2)

# %%
#Sonar Shot Points Plot
fig, ax = plt.subplots(1, 2, figsize=(8,4))

#Left, Top Down
ax[0].set_title("Overhead")
lines.plot(ax=ax[0], lw=1, alpha=0.5)
ax[0].set_aspect('equal')

#Right, Side View From South
ax[1].set_title("Side")
xz_l = [np.array([[l[0], l[2]]  for l in geom.coords[:]]) for geom in lines.geometry.values]

for xz in xz_l:
    a = np.array(xz)
    ax[1].plot(a[:,0], a[:,1], color='tab:blue', alpha=0.5, lw=1)
ax[1].set_aspect('equal')


fig.suptitle('DMV Example, Wireframe')
plt.show()

# %% [markdown]
# ---
# # Single Example, DAT

# %%
## Single Example
lat, long = 30.0161506, -93.3387168
elev = 1
surveyxyzWGS84 = (long, lat, elev)

# Desired Coordinate Reference System (X,Y,Z)
crs = 'EPSG:3452'
x, y, z = 2646201.88, 556917.16, 3
surveyxyz = (x,y,z)

year = 2025 + (7-1/12) + 23/365

# Offset in Cartesian Space of the Desired CRS of the 
#    well bore at the top of the sonar survey
dx, dy, dz = 5, 4, 3

# Set up SonarPy object
sp = SonarPy(surveyxyz=surveyxyz, # x,y,z of well head
             surveyxyzWGS84=surveyxyzWGS84, # WGS84 xyz of wellhead, for finding correct UTM Zone
             crs=crs,
             year=year,
             #utm_shp_path='World_UTM_Grid.shp' # Turn on in Colab
            )
    
print('MagDec:', sp.magdec)

path = "./data/example_dat.dat"

dfT = sp.dat_to_dfT(path) # SaltPy 0.0.6a and earlier will kick error on this function on some dat files

xyz = sp.dfT_to_xyz_delta_points(dfT)
xyzUTM3, xyzCRS3 = sp.generate_gdf(xyz, wb_delta=(dx,dy,dz)) #no wb_delta
# Out:
# MagDec: 0.0

# %%
# Build bottom endcap
v_vertices, v_faces = SonarPyVista.build_endcap(xyzUTM[xyzUTM.depth == 3270])

# %%
# Build horizontal shot section
h_vertices, h_faces = SonarPyVista.build_horizontal_shots(xyzUTM[xyzUTM.tilt == 0])

# Build bottom endcap
v_vertices, v_faces = SonarPyVista.build_endcap(xyzUTM[xyzUTM.depth == 3270])

# Switch normals with the rotation
v_faces = [x[::-1] for x in v_faces]

## Combine and Save - Errors in the STL will crash your kernal.
# Many STL tools are wrappers and will not give normal pythonic error messages.

SonarPyVista.combine_mesh_parts(
    parts=[
        (h_vertices, h_faces),
        (v_vertices, v_faces),
    ],
    filename="full_cave_mesh.stl"
)
# Out:
# Grouped by 'depth' into 78 layers.
# Combined mesh saved to: full_cave_mesh.stl

# %%
# Plot Mesh
mesh = pv.read("full_cave_mesh.stl")
mesh.plot()
# Out:
# Widget(value='<iframe src="http://localhost:53066/index.html?ui=P_0x21c791d09a0_0&reconnect=auto" class="pyvis…

# %% [markdown]
# ![Cavern STL Static Image](https://raw.githubusercontent.com/AgapitoInc/SaltPy/refs/heads/main/img/Cavern_Screenshot_for_static.png)
